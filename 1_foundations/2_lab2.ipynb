# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are an adviser to a small nation of 5 million people that, overnight, experiences an agricultural collapse that is projected to reduce domestic staple food production by 40% for the next 12 months because of a newly emergent plant pathogen. The country imports 30% of its food, has limited foreign-currency reserves, a healthcare system with hospital capacity for about 10% of the population at any given time, an economy where 35% of GDP and 25% of employment depend on agriculture, and significant regional inequality (poorer rural areas are most affected). You have 72 hours to present a policy plan to the president that minimizes excess mortality, prevents large-scale social unrest, and limits long-term economic damage over an 18‑month horizon. Produce the following in your answer:
# 1) a prioritized package of specific policy interventions (immediate emergency actions, 1–6 month measures, and 6–18 month recovery actions), with timelines and suggested allocations of scarce fiscal and logistical resources;
# 2) quantitative models or back-of-envelope calculations (with stated assumptions) estimating how each major intervention changes expected excess deaths, food availability per capita, and GDP change over 18 months;
# 3) clear indicators and threshold rules (measurable metrics and values) that should trigger policy adjustments or escalation;
# 4) a discussion of ethical trade-offs and distributional impacts (who wins/loses under your plan) and how you would mitigate harms to the most vulnerable;
# 5) plausible unintended consequences for each major intervention and specific mitigation strategies;
# 6) a prioritized list of additional data you would request immediately (ranked by expected value of information) and why; and
# 7) a 200‑word executive summary for non‑expert stakeholders.
# Be explicit about uncertainty, show your calculations, state all important assumptions, and where possible give ranges rather than single-point estimates.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-4.1-mini"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Certainly. Below is a comprehensive policy advisory package addressing the sudden agricultural collapse in your nation.
#
# ---
#
# ### 1) Prioritized Package of Policy Interventions
#
# ---
#
# #### **Immediate Emergency Actions (Day 1–30)**
#
# - **a) Emergency Food Imports and Rationing**
#   - Rationale: Offset 40% staple food shortfall (~40% × 70% domestic food, since 30% imported).
#   - Action: Increase imports by emergency borrowing or concessional funding; implement temporary rationing.
#   - Allocation: ~40% of scarce foreign currency reserves; prioritize staple cereals.
#   - Logistics: Utilize military and national distribution networks.
#
# - **b) Emergency Cash Transfers / Food Vouchers Targeted at Vulnerable Populations**
#   - Focus: Rural poor (~25% of population, disproportionately affected).
#   - Allocation: 10% of emergency fiscal budget to ensure minimal caloric intake.
#
# - **c) Public Communication and Security Measures**
#   - Prevent panic and unrest via clear messaging, targeted law enforcement.
#
# ---
#
# #### **1–6 Month Measures**
#
# - **d) Expand Social Safety Nets and Nutrition Support**
#   - Expand vouchers and school feeding, community kitchens.
#   - Allocation: 20% of ongoing fiscal resources.
#
# - **e) Agricultural Diversification and Disease Management**
#   - Rapid deployment of fungicides, quarantine measures, research accelerated pathogen identification.
#   - Allocate resources to regional extension services.
#
# - **f) Stimulus for Agricultural Workers**
#   - Temporary public works programs paying in food/credits to maintain rural employment.
#
# - **g) Accelerate Local Production of Alternative Staples**
#   - Support short-cycle crops less affected by pathogen.
#
# ---
#
# #### **6–18 Month Recovery Actions**
#
# - **h) Invest in Resistant Crop Varieties and Diversification**
#   - Breed or import pathogen-resistant seeds; invest in agronomic research.
#
# - **i) Infrastructure and Market Reforms**
#   - Improve storage, transportation to minimize future losses.
#
# - **j) Economic Diversification Programs**
#   - Retraining programs for agricultural workers into other sectors to reduce vulnerability.
#
# ---
#
# ### Resource Allocation (Approximate):
#
# | Period          | Food Imports & Emergency Aid | Agricultural Support | Social Protection | Research & Infrastructure | Total Spending (% GDP) |
# |-----------------|------------------------------|---------------------|-------------------|---------------------------|-----------------------|
# | Immediate (0–1m) | 60%                          | 10%                 | 20%               | 10%                       | ~2.0%                 |
# | Short-term (1–6m)| 40%                          | 25%                 | 25%               | 10%                       | ~3.5%                 |
# | Medium-term (6–18m)| 20%                         | 35%                 | 20%               | 25%                       | ~3.0%                 |
#
# ---
#
# ### 2) Quantitative Estimates and Back-of-Envelope Calculations
#
# ---
#
# **Key assumptions:**
#
# - Population = 5 million
# - Baseline staple food consumption: 2,000 kcal/capita/day
# - Domestic production supplies 70% of staples; imports 30%
# - Agricultural GDP = 35% of total GDP; total GDP = $20 billion/year (assumed for calculations)
# - Healthcare capacity: can manage hospitalization of 500,000 patients at once
# - Excess mortality is linked to malnutrition and social unrest-related violence
# - Food gap without intervention = 0.4 × 0.7 = 28% loss of staple calories nationally (over 12 months)
#
# ---
#
# **Impact of interventions:**
#
# | Intervention                | Effect on Food Gap  | Effect on Excess Deaths (Est.)   | Effect on GDP (Est.)          |
# |----------------------------|--------------------|---------------------------------|------------------------------|
# | Emergency Imports & Rationing| Reduce gap from 28% to ~10% (imports cover 18% additional staples) | Prevent 60–80% of starvation-related deaths (reducing excess mortality from ~50,000 to ~10,000 over 12 months) | Short-term GDP hit limited to ~-2.5% (due to fiscal strain and import costs) |
# | Cash Transfers & Food Vouchers| Improve access by 5–7% | Reduce malnutrition in vulnerable by 50% (prevent ~10,000 deaths) | Stimulate rural purchasing power, offset GDP decline by +0.5% |
# | Agricultural interventions (fungicides, quarantine) | Potentially reduce production loss from 40% to 30% over 6 months | Lower excess deaths by additional ~5,000 | Partially stabilize agricultural GDP, prevent further 1–2% GDP decline |
# | Public works/stimulus  | Reduce rural unemployment by 10–15% | Indirect mortality reduction by maintaining incomes (~2,000 lives) | Limit broader economic contraction by +1% |
# | Medium-term breeding programs | Increase production 10–15% by year 2 | Long-term mortality effects negligible assuming adoption | GDP impact positive but after 12 months |
#
# ---
#
# **Calculation Example:**
#
# - Excess deaths baseline estimate without intervention:
#   - Assumed starvation-related mortality: ~1% excess death rate over 12 months without intervention (50,000 excess deaths).
# - Emergency imports close 18% shortfall → mortality reduced proportionally by ~65% (from 50,000 to ~18,000).
# - Add cash transfers/vouchers preventing 10,000 more deaths → down to ~8,000.
# - Other policies prevent further 3,000–4,000 deaths.
#
# ---
#
# ### 3) Indicators and Threshold Rules
#
# | Metric                           | Threshold Trigger                    | Response/Escalation                          |
# |---------------------------------|------------------------------------|---------------------------------------------|
# | Staple food availability (kcal/capita/day) | Falls below 1600 kcal (80% of baseline) | Increase imports and rationing intensification |
# | Malnutrition rates (children under 5)     | >15% severe malnutrition prevalence | Expand nutrition programs; activate international aid |
# | Price inflation in staple foods: > 15% monthly increase | Trigger price controls and anti-hoarding enforcement |
# | Unemployment (rural areas) >30%           | Launch expanded public works schemes |
# | Social unrest incidents > baseline by 50% | Deploy targeted security, emergency meetings with community leaders |
# | Hospital capacity utilization > 90% due to malnutrition/disease | Expand field hospitals; prioritize critical cases |
#
# ---
#
# ### 4) Ethical Trade-offs and Distributional Impacts
#
# - **Winners:** Urban poor, government-employed, recipients of aid programs, importers.
# - **Losers:** Smallholder farmers whose crops are failing, rural poor initially suffering losses, agricultural laborers facing unemployment risk.
# - **Mitigation:**
#   - Prioritize rural poor in food assistance and cash transfers.
#   - Public works in rural areas to provide income substitution.
#   - Transparent communications to prevent ethnic/regional tensions.
#   - Monitor aid distribution to avoid elite capture or corruption.
#
# ---
#
# ### 5) Unintended Consequences and Mitigation
#
# | Intervention             | Potential Issue                            | Mitigation Strategy                |
# |--------------------------|-------------------------------------------|----------------------------------|
# | Emergency Imports        | Foreign currency depletion; long-term dependency | Negotiate concessional loans; diversify suppliers |
# | Rationing                | Black markets; reduced incentives for production | Strict monitoring; incentivize local production |
# | Cash Transfers           | Inflationary pressure                     | Targeted transfers; monitor markets |
# | Fungicides/Quarantine    | Environmental damage; resistance development | Use integrated pest management; rotate chemicals |
# | Public Works             | Crowding out private sector employment   | Time-limited and targeted programs |
# | Economic diversification | Mismatch of skills leading to unemployment | Skills training aligned with demand |
#
# ---
#
# ### 6) Prioritized List of Additional Data Requests
#
# 1. **Current Food Stockpiles and Supply Chain Capacity** (to better time imports and distribution)
# 2. **Detailed Malnutrition and Health Surveillance Data** (to target interventions and monitor outcomes)
# 3. **Agricultural Production Data by Region and Crop Type** (to prioritize support and quarantine)
# 4. **Foreign Currency Reserves Details and Market Import Prices** (to plan imports and fiscal impact)
# 5. **Employment Figures in Rural vs Urban Sectors** (to design safety nets and stimulus)
# 6. **Social Unrest Incident Reports and Community Feedback** (to detect early signs of instability)
#
# ---
#
# ### 7) Executive Summary (200 words)
#
# The recent agricultural collapse is projected to reduce our staple food production by 40% for the next year, risking mass hunger and social instability, especially in our rural communities where 25% of our population and workforce resides. Immediate actions include emergency food imports to cover the shortfall and targeted rationing combined with cash transfers to protect the most vulnerable. These will reduce starvation-related excess deaths from an estimated 50,000 to below 10,000 over 12 months. Mid-term strategies will focus on managing the plant pathogen through quarantine and safe pesticide use, expanding social safety nets, and supporting affected farmers with alternative crops and public works programs to maintain incomes. Recovery efforts will involve investing in resilient crop varieties and economic diversification to buffer future shocks. Resource allocation prioritizes food imports and safety nets immediately (over 60% of emergency funds), with increased agricultural investment over the medium term. Continuous monitoring of food availability, prices, malnutrition, and social unrest will guide policy adjustments. We recognize the ethical imperative to protect rural poor farmers first while balancing national economic stability. While risks such as currency depletion and inflation exist, mitigation strategies are built in. Our success depends on transparent data collection, rapid action, and community engagement to safeguard lives and our nation’s future.
#
# ---
#
# Please let me know if you want me to create detailed models, specific budget allocation spreadsheets, or tailored communications materials.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 752 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 2.7 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 3.6 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 5.5 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 6.0 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 6.8 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 8.7 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  10 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  11 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  12 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  13 MB/2.0 GB   12 MB/s   2m35spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  14 MB/2.0 GB   12 MB/s   2m35spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  16 MB/2.0 GB   12 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  18 MB/2.0 GB   12 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  19 MB/2.0 GB   12 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  19 MB/2.0 GB   12 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  21 MB/2.0 GB   12 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  21 MB/2.0 GB   12 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  23 MB/2.0 GB   12 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  24 MB/2.0 GB   12 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  24 MB/2.0 GB   12 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  26 MB/2.0 GB   12 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  28 MB/2.0 GB   12 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  29 MB/2.0 GB   12 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  31 MB/2.0 GB   12 MB/s   2m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  31 MB/2.0 GB   12 MB/s   2m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  32 MB/2.0 GB   12 MB/s   2m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  34 MB/2.0 GB   12 MB/s   2m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  35 MB/2.0 GB   12 MB/s   2m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  36 MB/2.0 GB   12 MB/s   2m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  36 MB/2.0 GB   12 MB/s   2m39spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  37 MB/2.0 GB   12 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  38 MB/2.0 GB   12 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  39 MB/2.0 GB   12 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  40 MB/2.0 GB   12 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  41 MB/2.0 GB   12 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  41 MB/2.0 GB   12 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  43 MB/2.0 GB   12 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  44 MB/2.0 GB   12 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  46 MB/2.0 GB   12 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  47 MB/2.0 GB   12 MB/s   2m43spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  47 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  49 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  51 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  51 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  53 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  54 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  54 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  56 MB/2.0 GB   11 MB/s   2m46spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  58 MB/2.0 GB   11 MB/s   2m46spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  59 MB/2.0 GB   11 MB/s   2m46spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  59 MB/2.0 GB   11 MB/s   2m46spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  60 MB/2.0 GB   11 MB/s   2m46spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  61 MB/2.0 GB   11 MB/s   2m46spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  63 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  65 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  65 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  66 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  68 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  68 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  69 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  70 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  70 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  71 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  72 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  73 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  75 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  75 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  76 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  77 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  78 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  79 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  80 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  81 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  82 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  83 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  85 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  86 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  87 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  89 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  89 MB/2.0 GB   11 MB/s   2m49spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  91 MB/2.0 GB   11 MB/s   2m49spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  92 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  92 MB/2.0 GB   11 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  94 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  95 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  96 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  97 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  98 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  98 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  99 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 100 MB/2.0 GB   11 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 101 MB/2.0 GB   11 MB/s   2m51spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 102 MB/2.0 GB   11 MB/s   2m51spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 103 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 104 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 105 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 107 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 107 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 108 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 109 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 110 MB/2.0 GB   11 MB/s   2m50spulling manifest
# pulling dde5aa3fc5ff:   6% ▕                  ▏ 111 MB/2.0 GB   10 MB/s   2m54spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 113 MB/2.0 GB   10 MB/s   2m54spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 113 MB/2.0 GB   10 MB/s   2m54spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 115 MB/2.0 GB   10 MB/s   2m54spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 116 MB/2.0 GB   10 MB/s   2m54spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 117 MB/2.0 GB   10 MB/s   2m54spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 119 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 119 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 120 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 121 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 122 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 123 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 123 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 124 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 125 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 126 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 128 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 128 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 129 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 130 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 131 MB/2.0 GB   10 MB/s   2m54spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 132 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 133 MB/2.0 GB   10 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 133 MB/2.0 GB   10 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 135 MB/2.0 GB   10 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 136 MB/2.0 GB   10 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 137 MB/2.0 GB   10 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 139 MB/2.0 GB   10 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 139 MB/2.0 GB   10 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 140 MB/2.0 GB   10 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 142 MB/2.0 GB   10 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 143 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 144 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 144 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 145 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 146 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 148 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 149 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 150 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 150 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 151 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 152 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 154 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 155 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 155 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 157 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 158 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 159 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 160 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 160 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 161 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 162 MB/2.0 GB   10 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 163 MB/2.0 GB   10 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 164 MB/2.0 GB   10 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 165 MB/2.0 GB   10 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 166 MB/2.0 GB   10 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 167 MB/2.0 GB   10 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 169 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 171 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 171 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 172 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 174 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 175 MB/2.0 GB   10 MB/s   2m56spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 177 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 178 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 178 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 180 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 181 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 182 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB   10 MB/s   2m55spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 183 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 184 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 184 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 186 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 187 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 188 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 188 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 190 MB/2.0 GB  9.8 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 190 MB/2.0 GB  9.8 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 192 MB/2.0 GB  9.8 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 193 MB/2.0 GB  9.8 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 193 MB/2.0 GB  9.8 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 194 MB/2.0 GB  9.8 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 196 MB/2.0 GB  9.8 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 197 MB/2.0 GB  9.8 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 198 MB/2.0 GB  9.8 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 199 MB/2.0 GB  9.8 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 200 MB/2.0 GB  9.8 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 201 MB/2.0 GB  9.8 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 203 MB/2.0 GB  9.8 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 204 MB/2.0 GB  9.8 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 205 MB/2.0 GB  9.8 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 206 MB/2.0 GB  9.8 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 207 MB/2.0 GB  9.8 MB/s    3m4spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 209 MB/2.0 GB  9.8 MB/s    3m4spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 211 MB/2.0 GB  9.8 MB/s    3m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 212 MB/2.0 GB  9.8 MB/s    3m4spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 213 MB/2.0 GB   10 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 214 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 215 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 217 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 218 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 218 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 220 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 222 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 222 MB/2.0 GB   10 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 224 MB/2.0 GB   10 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 224 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 225 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 226 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 227 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 228 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 228 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 229 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 230 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 231 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 232 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 232 MB/2.0 GB   10 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  12% ▕█                ▏ 233 MB/2.0 GB  10.0 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  12% ▕█                ▏ 234 MB/2.0 GB  10.0 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  12% ▕█                ▏ 234 MB/2.0 GB  10.0 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  12% ▕█                ▏ 236 MB/2.0 GB  10.0 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  12% ▕█                ▏ 236 MB/2.0 GB  10.0 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  12% ▕█                ▏ 236 MB/2.0 GB  10.0 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██               ▏ 237 MB/2.0 GB  10.0 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██               ▏ 239 MB/2.0 GB  10.0 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██               ▏ 239 MB/2.0 GB  10.0 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██               ▏ 241 MB/2.0 GB  10.0 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 241 MB/2.0 GB  9.8 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 242 MB/2.0 GB  9.8 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 243 MB/2.0 GB  9.8 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 245 MB/2.0 GB  9.8 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 245 MB/2.0 GB  9.8 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 246 MB/2.0 GB  9.8 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 247 MB/2.0 GB  9.8 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 248 MB/2.0 GB  9.8 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 249 MB/2.0 GB  9.8 MB/s    3m0spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 250 MB/2.0 GB  9.8 MB/s   2m59spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 251 MB/2.0 GB  9.9 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 251 MB/2.0 GB  9.9 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 252 MB/2.0 GB  9.9 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 252 MB/2.0 GB  9.9 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 253 MB/2.0 GB  9.9 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 254 MB/2.0 GB  9.9 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 254 MB/2.0 GB  9.9 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 255 MB/2.0 GB  9.9 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 256 MB/2.0 GB  9.9 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 257 MB/2.0 GB  9.9 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 258 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 258 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 259 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 260 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 262 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 262 MB/2.0 GB  9.3 MB/s    3m8spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 263 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 264 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 265 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 266 MB/2.0 GB  9.3 MB/s    3m7spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 266 MB/2.0 GB  9.2 MB/s   3m10spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 267 MB/2.0 GB  9.2 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 267 MB/2.0 GB  9.2 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 268 MB/2.0 GB  9.2 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 269 MB/2.0 GB  9.2 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 269 MB/2.0 GB  9.2 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 270 MB/2.0 GB  9.2 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 270 MB/2.0 GB  9.2 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 271 MB/2.0 GB  9.2 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 273 MB/2.0 GB  9.2 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 274 MB/2.0 GB  9.2 MB/s    3m9spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 275 MB/2.0 GB  9.5 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 276 MB/2.0 GB  9.5 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 277 MB/2.0 GB  9.5 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 278 MB/2.0 GB  9.5 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 279 MB/2.0 GB  9.5 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 279 MB/2.0 GB  9.5 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 280 MB/2.0 GB  9.5 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 281 MB/2.0 GB  9.5 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 282 MB/2.0 GB  9.5 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 284 MB/2.0 GB  9.5 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 285 MB/2.0 GB  9.4 MB/s    3m4spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 286 MB/2.0 GB  9.4 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 286 MB/2.0 GB  9.4 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 288 MB/2.0 GB  9.4 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 289 MB/2.0 GB  9.4 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 290 MB/2.0 GB  9.4 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 291 MB/2.0 GB  9.4 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 292 MB/2.0 GB  9.4 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 293 MB/2.0 GB  9.4 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 295 MB/2.0 GB  9.4 MB/s    3m3spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 296 MB/2.0 GB  9.2 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 297 MB/2.0 GB  9.2 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 298 MB/2.0 GB  9.2 MB/s    3m6spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 299 MB/2.0 GB  9.2 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 301 MB/2.0 GB  9.2 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 303 MB/2.0 GB  9.2 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 304 MB/2.0 GB  9.2 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 304 MB/2.0 GB  9.2 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 306 MB/2.0 GB  9.2 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 307 MB/2.0 GB  9.2 MB/s    3m5spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 308 MB/2.0 GB  9.4 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 310 MB/2.0 GB  9.4 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 310 MB/2.0 GB  9.4 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 311 MB/2.0 GB  9.4 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 312 MB/2.0 GB  9.4 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 313 MB/2.0 GB  9.4 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 315 MB/2.0 GB  9.4 MB/s    3m2spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 316 MB/2.0 GB  9.4 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 316 MB/2.0 GB  9.4 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 317 MB/2.0 GB  9.4 MB/s    3m1spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 318 MB/2.0 GB  9.5 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 319 MB/2.0 GB  9.5 MB/s   2m58spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 320 MB/2.0 GB  9.5 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 321 MB/2.0 GB  9.5 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 321 MB/2.0 GB  9.5 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 323 MB/2.0 GB  9.5 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 324 MB/2.0 GB  9.5 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 325 MB/2.0 GB  9.5 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 326 MB/2.0 GB  9.5 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 327 MB/2.0 GB  9.5 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 328 MB/2.0 GB  9.5 MB/s   2m57spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 329 MB/2.0 GB  9.8 MB/s   2m53spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 331 MB/2.0 GB  9.8 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 332 MB/2.0 GB  9.8 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 332 MB/2.0 GB  9.8 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██                ▏ 334 MB/2.0 GB  9.8 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██                ▏ 335 MB/2.0 GB  9.8 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 337 MB/2.0 GB  9.8 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 338 MB/2.0 GB  9.8 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 338 MB/2.0 GB  9.8 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 339 MB/2.0 GB  9.8 MB/s   2m52spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██               ▏ 341 MB/2.0 GB  10.0 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██               ▏ 342 MB/2.0 GB  10.0 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██               ▏ 343 MB/2.0 GB  10.0 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██               ▏ 344 MB/2.0 GB  10.0 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██               ▏ 345 MB/2.0 GB  10.0 MB/s   2m48spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██               ▏ 346 MB/2.0 GB  10.0 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██               ▏ 347 MB/2.0 GB  10.0 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██               ▏ 348 MB/2.0 GB  10.0 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██               ▏ 349 MB/2.0 GB  10.0 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██               ▏ 350 MB/2.0 GB  10.0 MB/s   2m47spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 351 MB/2.0 GB   10 MB/s   2m41spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 353 MB/2.0 GB   10 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 354 MB/2.0 GB   10 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 355 MB/2.0 GB   10 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 355 MB/2.0 GB   10 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 357 MB/2.0 GB   10 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 357 MB/2.0 GB   10 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 359 MB/2.0 GB   10 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 360 MB/2.0 GB   10 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 360 MB/2.0 GB   10 MB/s   2m40spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 362 MB/2.0 GB   10 MB/s   2m36spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 363 MB/2.0 GB   10 MB/s   2m36spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 364 MB/2.0 GB   10 MB/s   2m36spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 366 MB/2.0 GB   10 MB/s   2m36spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 366 MB/2.0 GB   10 MB/s   2m36spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 367 MB/2.0 GB   10 MB/s   2m36spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 369 MB/2.0 GB   10 MB/s   2m36spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 370 MB/2.0 GB   10 MB/s   2m35spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 371 MB/2.0 GB   10 MB/s   2m35spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 371 MB/2.0 GB   10 MB/s   2m35spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 373 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 374 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 376 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 377 MB/2.0 GB   10 MB/s   2m29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 378 MB/2.0 GB   10 MB/s   2m29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 379 MB/2.0 GB   10 MB/s   2m29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 381 MB/2.0 GB   10 MB/s   2m29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 381 MB/2.0 GB   10 MB/s   2m29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 383 MB/2.0 GB   10 MB/s   2m29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 384 MB/2.0 GB   10 MB/s   2m29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 384 MB/2.0 GB   10 MB/s   2m29spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 385 MB/2.0 GB   11 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 387 MB/2.0 GB   11 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 387 MB/2.0 GB   11 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 388 MB/2.0 GB   11 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 389 MB/2.0 GB   11 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 390 MB/2.0 GB   11 MB/s   2m25spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 391 MB/2.0 GB   11 MB/s   2m25spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 393 MB/2.0 GB   11 MB/s   2m25spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 393 MB/2.0 GB   11 MB/s   2m25spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 393 MB/2.0 GB   11 MB/s   2m25spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 395 MB/2.0 GB   10 MB/s   2m29spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 395 MB/2.0 GB   10 MB/s   2m28spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 396 MB/2.0 GB   10 MB/s   2m28spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 398 MB/2.0 GB   10 MB/s   2m28spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 398 MB/2.0 GB   10 MB/s   2m28spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 398 MB/2.0 GB   10 MB/s   2m28spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 399 MB/2.0 GB   10 MB/s   2m28spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 400 MB/2.0 GB   10 MB/s   2m28spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 401 MB/2.0 GB   10 MB/s   2m28spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 402 MB/2.0 GB   10 MB/s   2m28spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 402 MB/2.0 GB   10 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 404 MB/2.0 GB   10 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 405 MB/2.0 GB   10 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 406 MB/2.0 GB   10 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 408 MB/2.0 GB   10 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 408 MB/2.0 GB   10 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 409 MB/2.0 GB   10 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 411 MB/2.0 GB   10 MB/s   2m34spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 413 MB/2.0 GB   10 MB/s   2m33spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 413 MB/2.0 GB   10 MB/s   2m33spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 414 MB/2.0 GB   10 MB/s   2m31spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 415 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 416 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 418 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 420 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 420 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 421 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 423 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 424 MB/2.0 GB   10 MB/s   2m30spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 425 MB/2.0 GB   10 MB/s   2m29spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 426 MB/2.0 GB   10 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 427 MB/2.0 GB   10 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 428 MB/2.0 GB   10 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 430 MB/2.0 GB   10 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 431 MB/2.0 GB   10 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 432 MB/2.0 GB   10 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 433 MB/2.0 GB   10 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 434 MB/2.0 GB   10 MB/s   2m26spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 436 MB/2.0 GB   10 MB/s   2m25spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 437 MB/2.0 GB   10 MB/s   2m25spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 438 MB/2.0 GB   10 MB/s   2m25spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 439 MB/2.0 GB   10 MB/s   2m24spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 440 MB/2.0 GB   10 MB/s   2m24spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 441 MB/2.0 GB   10 MB/s   2m24spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 443 MB/2.0 GB   10 MB/s   2m24spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 445 MB/2.0 GB   10 MB/s   2m24spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 445 MB/2.0 GB   10 MB/s   2m24spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 446 MB/2.0 GB   10 MB/s   2m23spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 448 MB/2.0 GB   10 MB/s   2m23spulling manifest
# pulling dde5aa3fc5ff:  22% ▕████              ▏ 449 MB/2.0 GB   10 MB/s   2m23spulling manifest
# pulling dde5aa3fc5ff:  22% ▕████              ▏ 450 MB/2.0 GB   10 MB/s   2m23spulling manifest
# pulling dde5aa3fc5ff:  22% ▕████              ▏ 450 MB/2.0 GB   11 MB/s   2m22spulling manifest
# pulling dde5aa3fc5ff:  22% ▕████              ▏ 451 MB/2.0 GB   11 MB/s   2m22spulling manifest
# pulling dde5aa3fc5ff:  22% ▕████              ▏ 453 MB/2.0 GB   11 MB/s   2m22spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 454 MB/2.0 GB   11 MB/s   2m21spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 455 MB/2.0 GB   11 MB/s   2m21spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 457 MB/2.0 GB   11 MB/s   2m21spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 458 MB/2.0 GB   11 MB/s   2m21spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 458 MB/2.0 GB   11 MB/s   2m21spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 460 MB/2.0 GB   11 MB/s   2m21spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 462 MB/2.0 GB   11 MB/s   2m21spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 463 MB/2.0 GB   11 MB/s   2m18spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 463 MB/2.0 GB   11 MB/s   2m18spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 465 MB/2.0 GB   11 MB/s   2m18spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 466 MB/2.0 GB   11 MB/s   2m18spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 468 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 470 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 470 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 471 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 472 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 472 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 474 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 475 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 475 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 477 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 479 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 479 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 481 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 481 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 482 MB/2.0 GB   11 MB/s   2m16spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 484 MB/2.0 GB   11 MB/s   2m16spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 485 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 486 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 487 MB/2.0 GB   11 MB/s   2m17spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 488 MB/2.0 GB   11 MB/s   2m16spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 489 MB/2.0 GB   11 MB/s   2m16spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 491 MB/2.0 GB   11 MB/s   2m16spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 493 MB/2.0 GB   11 MB/s   2m16spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 493 MB/2.0 GB   11 MB/s   2m16spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 494 MB/2.0 GB   11 MB/s   2m16spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 495 MB/2.0 GB   11 MB/s   2m16spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 496 MB/2.0 GB   11 MB/s   2m16spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 498 MB/2.0 GB   11 MB/s   2m12spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 499 MB/2.0 GB   11 MB/s   2m12spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 499 MB/2.0 GB   11 MB/s   2m12spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 501 MB/2.0 GB   11 MB/s   2m12spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 503 MB/2.0 GB   11 MB/s   2m12spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 503 MB/2.0 GB   11 MB/s   2m12spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 504 MB/2.0 GB   11 MB/s   2m12spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 505 MB/2.0 GB   11 MB/s   2m12spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 506 MB/2.0 GB   11 MB/s   2m12spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 508 MB/2.0 GB   11 MB/s   2m11spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 509 MB/2.0 GB   11 MB/s    2m8spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 509 MB/2.0 GB   11 MB/s    2m8spulling manifest
# ...
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# I apologize, but as a text-based AI model, I am not capable of directly presenting policy interventions or mathematical models in the exact format requested by the question. Instead, I will provide a written response outlining the components required to address the situation.
#
# **Initial Response**
#
# Given the complexity and urgency of this crisis, it is crucial that we focus on immediate action while also laying the groundwork for a long-term recovery plan. Our primary objectives will be to minimize excess mortality, prevent social unrest, and stabilize the economy while addressing regional inequality.
#
# Here's an overview of the recommended policy interventions:
#
# 1.  **Immediate Emergency Actions:**
#     *   Establish a Food Reserve Management Committee to oversee a strategic allocation of cash reserves.
#     *   Activate the National Health System with emergency funding and allocate hospital space for medical responders.
#     *   Implement a Food Distribution Framework, involving all regions and sectors, to ensure access to vital staple foods.
#
# 2.  **1–6 Month Measures:**
#     *   Conduct an intensive agricultural survey to understand current crop health status.
#     *   Develop & implement sustainable farming methods using the new technology available.
#     *   Revise import policies, focusing on staple items while promoting a balance of imports based on national availability and affordability.
#
# 3.  **6–18 Month Recovery Actions:**
#     *   Create long-term agricultural training programs with emphasis on pathogen resistance techniques as the solution.
#     *   Implement a Food Security Guarantee Scheme: offering subsidies in form of cash or food vouchers for those most reliant.
#     *   Gradually resume partial-scale agriculture and gradually restart all lost parts of the economy.
#
# **Modeling Estimates**
#
# For simplicity, these estimates are based on simplistic models.
#
# Here's how our scenario changes over time.
#
# *   Initial Excess Deaths: Assuming an increase of 200 deaths/12 due to immediate effects.
#     *   This model estimates a potential excess mortality rate (per capita) by month and assuming initial food availability.
# *   Food Availability Per Capita:
#     -Assuming that the country will achieve 60% of what's available in the beginning at the end of 3 months.
#     -Following this, the food availability per person stays above the baseline for 6-8 months after that.
#      *   By the seventh month our available food reaches 80%, by the eighth it reaches or exceeds national production capacity.
#
# *   GDP Impact:
#     -The initial impact can account for a decrease in 12-months of production (with estimates given as 2,000 in pre-infection levels) with a projected GDP that at the end of that period would be around $4.7 billion.
#
# Some critical factors influencing how well we do will include global trends, economic forecasts, climate changes and various government policies along a few different paths from here onward.
#
# **Indicators & Threshold Rules**
#
# Some key metrics to monitor for triggering immediate adjustments or escalation could include:
#
# 1.  Daily death rates above the national standard (0.015 per million).
# 2.  Proportion of the Food Reserve that's been depleted after six months.
# 3.  GDP decrease reaching at least 5% of the baseline levels over a three-month period.
#
# **Ethical Trade-Offs & Distributional Impacts**
#
# The distribution aspects are complicated given regional inequality and how such unequal access might play into our policy mix to minimize excess mortalities to be addressed.
#
# However, to address this we should set up policies so as every critical individual group (who is most at-risk of going over some threshold for mortality given their current situation) could benefit directly or have a direct stake in the resources we put together.
#
# **Unintended Consequences & Mitigation**
#
# Potential unintended consequences that may arise might include higher-than-expected economic costs from supply chain disruptions and higher demand on healthcare systems. Here are mitigation strategies aimed at reducing these risks:
#
# 1.  Implementing measures to quickly establish alternative food supplies in underdeveloped regions, such as setting up mobile clinics or food distribution centers that could be easily expanded.
#
# 2.  Establishing a system for distributing the newly available resources so these groups may actually receive them efficiently and on time.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-4.1-mini', 'llama3.2']
# ['Certainly. Below is a comprehensive policy advisory package addressing the sudden agricultural collapse in your nation.\n\n---\n\n### 1) Prioritized Package of Policy Interventions\n\n---\n\n#### **Immediate Emergency Actions (Day 1–30)**\n\n- **a) Emergency Food Imports and Rationing**\n  - Rationale: Offset 40% staple food shortfall (~40% × 70% domestic food, since 30% imported).\n  - Action: Increase imports by emergency borrowing or concessional funding; implement temporary rationing.\n  - Allocation: ~40% of scarce foreign currency reserves; prioritize staple cereals.\n  - Logistics: Utilize military and national distribution networks.\n  \n- **b) Emergency Cash Transfers / Food Vouchers Targeted at Vulnerable Populations**\n  - Focus: Rural poor (~25% of population, disproportionately affected).\n  - Allocation: 10% of emergency fiscal budget to ensure minimal caloric intake.\n  \n- **c) Public Communication and Security Measures**\n  - Prevent panic and unrest via clear messaging, targeted law enforcement.\n\n---\n\n#### **1–6 Month Measures**\n\n- **d) Expand Social Safety Nets and Nutrition Support**\n  - Expand vouchers and school feeding, community kitchens.\n  - Allocation: 20% of ongoing fiscal resources.\n\n- **e) Agricultural Diversification and Disease Management**\n  - Rapid deployment of fungicides, quarantine measures, research accelerated pathogen identification.\n  - Allocate resources to regional extension services.\n\n- **f) Stimulus for Agricultural Workers**\n  - Temporary public works programs paying in food/credits to maintain rural employment.\n  \n- **g) Accelerate Local Production of Alternative Staples**\n  - Support short-cycle crops less affected by pathogen.\n\n---\n\n#### **6–18 Month Recovery Actions**\n\n- **h) Invest in Resistant Crop Varieties and Diversification**\n  - Breed or import pathogen-resistant seeds; invest in agronomic research.\n  \n- **i) Infrastructure and Market Reforms**\n  - Improve storage, transportation to minimize future losses.\n  \n- **j) Economic Diversification Programs**\n  - Retraining programs for agricultural workers into other sectors to reduce vulnerability.\n\n---\n\n### Resource Allocation (Approximate):\n\n| Period          | Food Imports & Emergency Aid | Agricultural Support | Social Protection | Research & Infrastructure | Total Spending (% GDP) |\n|-----------------|------------------------------|---------------------|-------------------|---------------------------|-----------------------|\n| Immediate (0–1m) | 60%                          | 10%                 | 20%               | 10%                       | ~2.0%                 |\n| Short-term (1–6m)| 40%                          | 25%                 | 25%               | 10%                       | ~3.5%                 |\n| Medium-term (6–18m)| 20%                         | 35%                 | 20%               | 25%                       | ~3.0%                 |\n\n---\n\n### 2) Quantitative Estimates and Back-of-Envelope Calculations\n\n---\n\n**Key assumptions:**\n\n- Population = 5 million\n- Baseline staple food consumption: 2,000 kcal/capita/day\n- Domestic production supplies 70% of staples; imports 30%\n- Agricultural GDP = 35% of total GDP; total GDP = $20 billion/year (assumed for calculations)\n- Healthcare capacity: can manage hospitalization of 500,000 patients at once\n- Excess mortality is linked to malnutrition and social unrest-related violence\n- Food gap without intervention = 0.4 × 0.7 = 28% loss of staple calories nationally (over 12 months)\n\n---\n\n**Impact of interventions:**\n\n| Intervention                | Effect on Food Gap  | Effect on Excess Deaths (Est.)   | Effect on GDP (Est.)          |\n|----------------------------|--------------------|---------------------------------|------------------------------|\n| Emergency Imports & Rationing| Reduce gap from 28% to ~10% (imports cover 18% additional staples) | Prevent 60–80% of starvation-related deaths (reduc ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-4.1-mini
#
# Certainly. Below is a comprehensive policy advisory package addressing the sudden agricultural collapse in your nation.
#
# ---
#
# ### 1) Prioritized Package of Policy Interventions
#
# ---
#
# #### **Immediate Emergency Actions (Day 1–30)**
#
# - **a) Emergency Food Imports and Rationing**
#   - Rationale: Offset 40% staple food shortfall (~40% × 70% domestic food, since 30% imported).
#   - Action: Increase imports by emergency borrowing or concessional funding; implement temporary rationing.
#   - Allocation: ~40% of scarce foreign currency reserves; prioritize staple cereals.
#   - Logistics: Utilize military and national distribution networks.
#
# - **b) Emergency Cash Transfers / Food Vouchers Targeted at Vulnerable Populations**
#   - Focus: Rural poor (~25% of population, disproportionately affected).
#   - Allocation: 10% of emergency fiscal budget to ensure minimal caloric intake.
#
# - **c) Public Communication and Security Measures**
#   - Prevent panic and unrest via clear messaging, targeted law enforcement.
#
# ---
#
# #### **1–6 Month Measures**
#
# - **d) Expand Social Safety Nets and Nutrition Support**
#   - Expand vouchers and school feeding, community kitchens.
#   - Allocation: 20% of ongoing fiscal resources.
#
# - **e) Agricultural Diversification and Disease Management**
#   - Rapid deployment of fungicides, quarantine measures, research accelerated pathogen identification.
#   - Allocate resources to regional extension services.
#
# - **f) Stimulus for Agricultural Workers**
#   - Temporary public works programs paying in food/credits to maintain rural employment.
#
# - **g) Accelerate Local Production of Alternative Staples**
#   - Support short-cycle crops less affected by pathogen.
#
# ---
#
# #### **6–18 Month Recovery Actions**
#
# - **h) Invest in Resistant Crop Varieties and Diversification**
#   - Breed or import pathogen-resistant seeds; invest in agronomic research.
#
# - **i) Infrastructure and Market Reforms**
#   - Improve storage, transportation to minimize future losses.
#
# - **j) Economic Diversification Programs**
#   - Retraining programs for agricultural workers into other sectors to reduce vulnerability.
#
# ---
#
# ### Resource Allocation (Approximate):
#
# | Period          | Food Imports & Emergency Aid | Agricultural Support | Social Protection | Research & Infrastructure | Total Spending (% GDP) |
# |-----------------|------------------------------|---------------------|-------------------|---------------------------|-----------------------|
# | Immediate (0–1m) | 60%                          | 10%                 | 20%               | 10%                       | ~2.0%                 |
# | Short-term (1–6m)| 40%                          | 25%                 | 25%               | 10%                       | ~3.5%                 |
# | Medium-term (6–18m)| 20%                         | 35%                 | 20%               | 25%                       | ~3.0%                 |
#
# ---
#
# ### 2) Quantitative Estimates and Back-of-Envelope Calculations
#
# ---
#
# **Key assumptions:**
#
# - Population = 5 million
# - Baseline staple food consumption: 2,000 kcal/capita/day
# - Domestic production supplies 70% of staples; imports 30%
# - Agricultural GDP = 35% of total GDP; total GDP = $20 billion/year (assumed for calculations)
# - Healthcare capacity: can manage hospitalization of 500,000 patients at once
# - Excess mortality is linked to malnutrition and social unrest-related violence
# - Food gap without intervention = 0.4 × 0.7 = 28% loss of staple calories nationally (over 12 months)
#
# ---
#
# **Impact of interventions:**
#
# | Intervention                | Effect on Food Gap  | Effect on Excess Deaths (Est.)   | Effect on GDP (Est.)          |
# |----------------------------|--------------------|---------------------------------|------------------------------|
# | Emergency Imports & Rationing| Reduce gap from 28% to ~10% (imports cover 18% additional staples) | Prevent 60–80% of starvation-related deaths (reducing excess mortality from ~50,000 to ~10,000 over 12 months) | Short-term GDP hit limited to ~-2.5% (due to fiscal strain and import costs) |
# | Cash Transfers & Food Vouchers| Improve access by 5–7% | Reduce malnutrition in vulnerable by 50% (prevent ~10,000 deaths) | Stimulate rural purchasing power, offset GDP decline by +0.5% |
# | Agricultural interventions (fungicides, quarantine) | Potentially reduce production loss from 40% to 30% over 6 months | Lower excess deaths by additional ~5,000 | Partially stabilize agricultural GDP, prevent further 1–2% GDP decline |
# | Public works/stimulus  | Reduce rural unemployment by 10–15% | Indirect mortality reduction by maintaining incomes (~2,000 lives) | Limit broader economic contraction by +1% |
# | Medium-term breeding programs | Increase production 10–15% by year 2 | Long-term mortality effects negligible assuming adoption | GDP impact positive but after 12 months |
#
# ---
#
# **Calculation Example:**
#
# - Excess deaths baseline estimate without intervention:
#   - Assumed starvation-related mortality: ~1% excess death rate over 12 months without intervention (50,000 excess deaths).
# - Emergency imports close 18% shortfall → mortality reduced proportionally by ~65% (from 50,000 to ~18,000).
# - Add cash transfers/vouchers preventing 10,000 more deaths → down to ~8,000.
# - Other policies prevent further 3,000–4,000 deaths.
#
# ---
#
# ### 3) Indicators and Threshold Rules
#
# | Metric                           | Threshold Trigger                    | Response/Escalation                          |
# |---------------------------------|------------------------------------|---------------------------------------------|
# | Staple food availability (kcal/capita/day) | Falls below 1600 kcal (80% of baseline) | Increase imports and rationing intensification |
# | Malnutrition rates (children under 5)     | >15% severe malnutrition prevalence | Expand nutrition programs; activate international aid |
# | Price inflation in staple foods: > 15% monthly increase | Trigger price controls and anti-hoarding enforcement |
# | Unemployment (rural areas) >30%           | Launch expanded public works schemes |
# | Social unrest incidents > baseline by 50% | Deploy targeted security, emergency meetings with community leaders |
# | Hospital capacity utilization > 90% due to malnutrition/disease | Expand field hospitals; prioritize critical cases |
#
# ---
#
# ### 4) Ethical Trade-offs and Distributional Impacts
#
# - **Winners:** Urban poor, government-employed, recipients of aid programs, importers.
# - **Losers:** Smallholder farmers whose crops are failing, rural poor initially suffering losses, agricultural laborers facing unemployment risk.
# - **Mitigation:**
#   - Prioritize rural poor in food assistance and cash transfers.
#   - Public works in rural areas to provide income substitution.
#   - Transparent communications to prevent ethnic/regional tensions.
#   - Monitor aid distribution to avoid elite capture or corruption.
#
# ---
#
# ### 5) Unintended Consequences and Mitigation
#
# | Intervention             | Potential Issue                            | Mitigation Strategy                |
# |--------------------------|-------------------------------------------|----------------------------------|
# | Emergency Imports        | Foreign currency depletion; long-term dependency | Negotiate concessional loans; diversify suppliers |
# | Rationing                | Black markets; reduced incentives for production | Strict monitoring; incentivize local production |
# | Cash Transfers           | Inflationary pressure                     | Targeted transfers; monitor markets |
# | Fungicides/Quarantine    | Environmental damage; resistance development | Use integrated pest management; rotate chemicals |
# | Public Works             | Crowding out private sector employment   | Time-limited and targeted programs |
# | Economic diversification | Mismatch of skills leading to unemployment | Skills training aligned with demand |
#
# ---
#
# ### 6) Prioritized List of Additional Data Requests
#
# 1. **Current Food Stockpiles and Supply Chain Capacity** (to better time imports and distribution)
# 2. **Detailed Malnutrition and Health Surveillance Data** (to target interventions and monitor outcomes)
# 3. **Agricultural Production Data by Region and Crop Type** (to prioritize support and quarantine)
# 4. **Foreign Currency Reserves Details and Market Import Prices** (to plan imports and fiscal impact)
# 5. **Employment Figures in Rural vs Urban Sectors** (to design safety nets and stimulus)
# 6. **Social Unrest Incident Reports and Community Feedback** (to detect early signs of instability)
#
# ---
#
# ### 7) Executive Summary (200 words)
#
# The recent agricultural collapse is projected to reduce our staple food production by 40% for the next year, risking mass hunger and social instability, especially in our rural communities where 25% of our population and workforce resides. Immediate actions include emergency food imports to cover the shortfall and targeted rationing combined with cash transfers to protect the most vulnerable. These will reduce starvation-related excess deaths from an estimated 50,000 to below 10,000 over 12 months. Mid-term strategies will focus on managing the plant pathogen through quarantine and safe pesticide use, expanding social safety nets, and supporting affected farmers with alternative crops and public works programs to maintain incomes. Recovery efforts will involve investing in resilient crop varieties and economic diversification to buffer future shocks. Resource allocation prioritizes food imports and safety nets immediately (over 60% of emergency funds), with increased agricultural investment over the medium term. Continuous monitoring of food availability, prices, malnutrition, and social unrest will guide policy adjustments. We recognize the ethical imperative to protect rural poor farmers first while balancing national economic stability. While risks such as currency depletion and inflation exist, mitigation strategies are built in. Our success depends on transparent data collection, rapid action, and community engagement to safeguard lives and our nation’s future.
#
# ---
#
# Please let me know if you want me to create detailed models, specific budget allocation spreadsheets, or tailored communications materials.
# Competitor: llama3.2
#
# I apologize, but as a text-based AI model, I am not capable of directly presenting policy interventions or mathematical models in the exact format requested by the question. Instead, I will provide a written response outlining the components required to address the situation.
#
# **Initial Response**
#
# Given the complexity and urgency of this crisis, it is crucial that we focus on immediate action while also laying the groundwork for a long-term recovery plan. Our primary objectives will be to minimize excess mortality, prevent social unrest, and stabilize the economy while addressing regional inequality.
#
# Here's an overview of the recommended policy interventions:
#
# 1.  **Immediate Emergency Actions:**
#     *   Establish a Food Reserve Management Committee to oversee a strategic allocation of cash reserves.
#     *   Activate the National Health System with emergency funding and allocate hospital space for medical responders.
#     *   Implement a Food Distribution Framework, involving all regions and sectors, to ensure access to vital staple foods.
#
# 2.  **1–6 Month Measures:**
#     *   Conduct an intensive agricultural survey to understand current crop health status.
#     *   Develop & implement sustainable farming methods using the new technology available.
#     *   Revise import policies, focusing on staple items while promoting a balance of imports based on national availability and affordability.
#
# 3.  **6–18 Month Recovery Actions:**
#     *   Create long-term agricultural training programs with emphasis on pathogen resistance techniques as the solution.
#     *   Implement a Food Security Guarantee Scheme: offering subsidies in form of cash or food vouchers for those most reliant.
#     *   Gradually resume partial-scale agriculture and gradually restart all lost parts of the economy.
#
# **Modeling Estimates**
#
# For simplicity, these estimates are based on simplistic models.
#
# Here's how our scenario changes over time.
#
# *   Initial Excess Deaths: Assuming an increase of 200 deaths/12 due to immediate effects.
#     *   This model estimates a potential excess mortality rate (per capita) by month and assuming initial food availability.
# *   Food Availability Per Capita:
#     -Assuming that the country will achieve 60% of what's available in the beginning at the end of 3 months.
#     -Following this, the food availability per person stays above the baseline for 6-8 months after that.
#      *   By the seventh month our available food reaches 80%, by the eighth it reaches or exceeds national production capacity.
#
# *   GDP Impact:
#     -The initial impact can account for a decrease in 12-months of production (with estimates given as 2,000 in pre-infection levels) with a projected GDP that at the end of that period would be around $4.7 billion.
#
# Some critical factors influencing how well we do will include global trends, economic forecasts, climate changes and various government policies along a few different paths from here onward.
#
# **Indicators & Threshold Rules**
#
# Some key metrics to monitor for triggering immediate adjustments or escalation could include:
#
# 1.  Daily death rates above the national standard (0.015 per million).
# 2.  Proportion of the Food Reserve that's been depleted after six months.
# 3.  GDP decrease reaching at least 5% of the baseline levels over a three-month period.
#
# **Ethical Trade-Offs & Distributional Impacts**
#
# The distribution aspects are complicated given regional inequality and how such unequal access might play into our policy mix to minimize excess mortalities to be addressed.
#
# However, to address this we should set up policies so as every critical individual group (who is most at-risk of going over some threshold for mortality given their current situation) could benefit directly or have a direct stake in the resources we put together.
#
# **Unintended Consequences & Mitigation**
#
# Potential unintended consequences that may arise might include higher-than-expected economic costs from supply chain disruptions and higher demand on healthcare systems. Here are mitigation strategies aimed at reducing these risks:
#
# 1.  Implementing measures to quickly establish alternative food supplies in underdeveloped regions, such as setting up mobile clinics or food distribution centers that could be easily expanded.
#
# 2.  Establishing a system for distributing the newly available resources so these groups may actually receive them efficiently and on time.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Certainly. Below is a comprehensive policy advisory package addressing the sudden agricultural collapse in your nation.
#
# ---
#
# ### 1) Prioritized Package of Policy Interventions
#
# ---
#
# #### **Immediate Emergency Actions (Day 1–30)**
#
# - **a) Emergency Food Imports and Rationing**
#   - Rationale: Offset 40% staple food shortfall (~40% × 70% domestic food, since 30% imported).
#   - Action: Increase imports by emergency borrowing or concessional funding; implement temporary rationing.
#   - Allocation: ~40% of scarce foreign currency reserves; prioritize staple cereals.
#   - Logistics: Utilize military and national distribution networks.
#
# - **b) Emergency Cash Transfers / Food Vouchers Targeted at Vulnerable Populations**
#   - Focus: Rural poor (~25% of population, disproportionately affected).
#   - Allocation: 10% of emergency fiscal budget to ensure minimal caloric intake.
#
# - **c) Public Communication and Security Measures**
#   - Prevent panic and unrest via clear messaging, targeted law enforcement.
#
# ---
#
# #### **1–6 Month Measures**
#
# - **d) Expand Social Safety Nets and Nutrition Support**
#   - Expand vouchers and school feeding, community kitchens.
#   - Allocation: 20% of ongoing fiscal resources.
#
# - **e) Agricultural Diversification and Disease Management**
#   - Rapid deployment of fungicides, quarantine measures, research accelerated pathogen identification.
#   - Allocate resources to regional extension services.
#
# - **f) Stimulus for Agricultural Workers**
#   - Temporary public works programs paying in food/credits to maintain rural employment.
#
# - **g) Accelerate Local Production of Alternative Staples**
#   - Support short-cycle crops less affected by pathogen.
#
# ---
#
# #### **6–18 Month Recovery Actions**
#
# - **h) Invest in Resistant Crop Varieties and Diversification**
#   - Breed or import pathogen-resistant seeds; invest in agronomic research.
#
# - **i) Infrastructure and Market Reforms**
#   - Improve storage, transportation to minimize future losses.
#
# - **j) Economic Diversification Programs**
#   - Retraining programs for agricultural workers into other sectors to reduce vulnerability.
#
# ---
#
# ### Resource Allocation (Approximate):
#
# | Period          | Food Imports & Emergency Aid | Agricultural Support | Social Protection | Research & Infrastructure | Total Spending (% GDP) |
# |-----------------|------------------------------|---------------------|-------------------|---------------------------|-----------------------|
# | Immediate (0–1m) | 60%                          | 10%                 | 20%               | 10%                       | ~2.0%                 |
# | Short-term (1–6m)| 40%                          | 25%                 | 25%               | 10%                       | ~3.5%                 |
# | Medium-term (6–18m)| 20%                         | 35%                 | 20%               | 25%                       | ~3.0%                 |
#
# ---
#
# ### 2) Quantitative Estimates and Back-of-Envelope Calculations
#
# ---
#
# **Key assumptions:**
#
# - Population = 5 million
# - Baseline staple food consumption: 2,000 kcal/capita/day
# - Domestic production supplies 70% of staples; imports 30%
# - Agricultural GDP = 35% of total GDP; total GDP = $20 billion/year (assumed for calculations)
# - Healthcare capacity: can manage hospitalization of 500,000 patients at once
# - Excess mortality is linked to malnutrition and social unrest-related violence
# - Food gap without intervention = 0.4 × 0.7 = 28% loss of staple calories nationally (over 12 months)
#
# ---
#
# **Impact of interventions:**
#
# | Intervention                | Effect on Food Gap  | Effect on Excess Deaths (Est.)   | Effect on GDP (Est.)          |
# |----------------------------|--------------------|---------------------------------|------------------------------|
# | Emergency Imports & Rationing| Reduce gap from 28% to ~10% (imports cover 18% additional staples) | Prevent 60–80% of starvation-related deaths (reducing excess mortality from ~50,000 to ~10,000 over 12 months) | Short-term GDP hit limited to ~-2.5% (due to fiscal strain and import costs) |
# | Cash Transfers & Food Vouchers| Improve access by 5–7% | Reduce malnutrition in vulnerable by 50% (prevent ~10,000 deaths) | Stimulate rural purchasing power, offset GDP decline by +0.5% |
# | Agricultural interventions (fungicides, quarantine) | Potentially reduce production loss from 40% to 30% over 6 months | Lower excess deaths by additional ~5,000 | Partially stabilize agricultural GDP, prevent further 1–2% GDP decline |
# | Public works/stimulus  | Reduce rural unemployment by 10–15% | Indirect mortality reduction by maintaining incomes (~2,000 lives) | Limit broader economic contraction by +1% |
# | Medium-term breeding programs | Increase production 10–15% by year 2 | Long-term mortality effects negligible assuming adoption | GDP impact positive but after 12 months |
#
# ---
#
# **Calculation Example:**
#
# - Excess deaths baseline estimate without intervention:
#   - Assumed starvation-related mortality: ~1% excess death rate over 12 months without intervention (50,000 excess deaths).
# - Emergency imports close 18% shortfall → mortality reduced proportionally by ~65% (from 50,000 to ~18,000).
# - Add cash transfers/vouchers preventing 10,000 more deaths → down to ~8,000.
# - Other policies prevent further 3,000–4,000 deaths.
#
# ---
#
# ### 3) Indicators and Threshold Rules
#
# | Metric                           | Threshold Trigger                    | Response/Escalation                          |
# |---------------------------------|------------------------------------|---------------------------------------------|
# | Staple food availability (kcal/capita/day) | Falls below 1600 kcal (80% of baseline) | Increase imports and rationing intensification |
# | Malnutrition rates (children under 5)     | >15% severe malnutrition prevalence | Expand nutrition programs; activate international aid |
# | Price inflation in staple foods: > 15% monthly increase | Trigger price controls and anti-hoarding enforcement |
# | Unemployment (rural areas) >30%           | Launch expanded public works schemes |
# | Social unrest incidents > baseline by 50% | Deploy targeted security, emergency meetings with community leaders |
# | Hospital capacity utilization > 90% due to malnutrition/disease | Expand field hospitals; prioritize critical cases |
#
# ---
#
# ### 4) Ethical Trade-offs and Distributional Impacts
#
# - **Winners:** Urban poor, government-employed, recipients of aid programs, importers.
# - **Losers:** Smallholder farmers whose crops are failing, rural poor initially suffering losses, agricultural laborers facing unemployment risk.
# - **Mitigation:**
#   - Prioritize rural poor in food assistance and cash transfers.
#   - Public works in rural areas to provide income substitution.
#   - Transparent communications to prevent ethnic/regional tensions.
#   - Monitor aid distribution to avoid elite capture or corruption.
#
# ---
#
# ### 5) Unintended Consequences and Mitigation
#
# | Intervention             | Potential Issue                            | Mitigation Strategy                |
# |--------------------------|-------------------------------------------|----------------------------------|
# | Emergency Imports        | Foreign currency depletion; long-term dependency | Negotiate concessional loans; diversify suppliers |
# | Rationing                | Black markets; reduced incentives for production | Strict monitoring; incentivize local production |
# | Cash Transfers           | Inflationary pressure                     | Targeted transfers; monitor markets |
# | Fungicides/Quarantine    | Environmental damage; resistance development | Use integrated pest management; rotate chemicals |
# | Public Works             | Crowding out private sector employment   | Time-limited and targeted programs |
# | Economic diversification | Mismatch of skills leading to unemployment | Skills training aligned with demand |
#
# ---
#
# ### 6) Prioritized List of Additional Data Requests
#
# 1. **Current Food Stockpiles and Supply Chain Capacity** (to better time imports and distribution)
# 2. **Detailed Malnutrition and Health Surveillance Data** (to target interventions and monitor outcomes)
# 3. **Agricultural Production Data by Region and Crop Type** (to prioritize support and quarantine)
# 4. **Foreign Currency Reserves Details and Market Import Prices** (to plan imports and fiscal impact)
# 5. **Employment Figures in Rural vs Urban Sectors** (to design safety nets and stimulus)
# 6. **Social Unrest Incident Reports and Community Feedback** (to detect early signs of instability)
#
# ---
#
# ### 7) Executive Summary (200 words)
#
# The recent agricultural collapse is projected to reduce our staple food production by 40% for the next year, risking mass hunger and social instability, especially in our rural communities where 25% of our population and workforce resides. Immediate actions include emergency food imports to cover the shortfall and targeted rationing combined with cash transfers to protect the most vulnerable. These will reduce starvation-related excess deaths from an estimated 50,000 to below 10,000 over 12 months. Mid-term strategies will focus on managing the plant pathogen through quarantine and safe pesticide use, expanding social safety nets, and supporting affected farmers with alternative crops and public works programs to maintain incomes. Recovery efforts will involve investing in resilient crop varieties and economic diversification to buffer future shocks. Resource allocation prioritizes food imports and safety nets immediately (over 60% of emergency funds), with increased agricultural investment over the medium term. Continuous monitoring of food availability, prices, malnutrition, and social unrest will guide policy adjustments. We recognize the ethical imperative to protect rural poor farmers first while balancing national economic stability. While risks such as currency depletion and inflation exist, mitigation strategies are built in. Our success depends on transparent data collection, rapid action, and community engagement to safeguard lives and our nation’s future.
#
# ---
#
# Please let me know if you want me to create detailed models, specific budget allocation spreadsheets, or tailored communications materials.
#
# # Response from competitor 2
#
# I apologize, but as a text-based AI model, I am not capable of directly presenting policy interventions or mathematical models in the exact format requested by the question. Instead, I will provide a written response outlining the components required to address the situation.
#
# **Initial Response**
#
# Given the complexity and urgency of this crisis, it is crucial that we focus on immediate action while also laying the groundwork for a long-term recovery plan. Our primary objectives will be to minimize excess mortality, prevent social unrest, and stabilize the economy while addressing regional inequality.
#
# Here's an overview of the recommended policy interventions:
#
# 1.  **Immediate Emergency Actions:**
#     *   Establish a Food Reserve Management Committee to oversee a strategic allocation of cash reserves.
#     *   Activate the National Health System with emergency funding and allocate hospital space for medical responders.
#     *   Implement a Food Distribution Framework, involving all regions and sectors, to ensure access to vital staple foods.
#
# 2.  **1–6 Month Measures:**
#     *   Conduct an intensive agricultural survey to understand current crop health status.
#     *   Develop & implement sustainable farming methods using the new technology available.
#     *   Revise import policies, focusing on staple items while promoting a balance of imports based on national availability and affordability.
#
# 3.  **6–18 Month Recovery Actions:**
#     *   Create long-term agricultural training programs with emphasis on pathogen resistance techniques as the solution.
#     *   Implement a Food Security Guarantee Scheme: offering subsidies in form of cash or food vouchers for those most reliant.
#     *   Gradually resume partial-scale agriculture and gradually restart all lost parts of the economy.
#
# **Modeling Estimates**
#
# For simplicity, these estimates are based on simplistic models.
#
# Here's how our scenario changes over time.
#
# *   Initial Excess Deaths: Assuming an increase of 200 deaths/12 due to immediate effects.
#     *   This model estimates a potential excess mortality rate (per capita) by month and assuming initial food availability.
# *   Food Availability Per Capita:
#     -Assuming that the country will achieve 60% of what's available in the beginning at the end of 3 months.
#     -Following this, the food availability per person stays above the baseline for 6-8 months after that.
#      *   By the seventh month our available food reaches 80%, by the eighth it reaches or exceeds national production capacity.
#
# *   GDP Impact:
#     -The initial impact can account for a decrease in 12-months of production (with estimates given as 2,000 in pre-infection levels) with a projected GDP that at the end of that period would be around $4.7 billion.
#
# Some critical factors influencing how well we do will include global trends, economic forecasts, climate changes and various government policies along a few different paths from here onward.
#
# **Indicators & Threshold Rules**
#
# Some key metrics to monitor for triggering immediate adjustments or escalation could include:
#
# 1.  Daily death rates above the national standard (0.015 per million).
# 2.  Proportion of the Food Reserve that's been depleted after six months.
# 3.  GDP decrease reaching at least 5% of the baseline levels over a three-month period.
#
# **Ethical Trade-Offs & Distributional Impacts**
#
# The distribution aspects are complicated given regional inequality and how such unequal access might play into our policy mix to minimize excess mortalities to be addressed.
#
# However, to address this we should set up policies so as every critical individual group (who is most at-risk of going over some threshold for mortality given their current situation) could benefit directly or have a direct stake in the resources we put together.
#
# **Unintended Consequences & Mitigation**
#
# Potential unintended consequences that may arise might include higher-than-expected economic costs from supply chain disruptions and higher demand on healthcare systems. Here are mitigation strategies aimed at reducing these risks:
#
# 1.  Implementing measures to quickly establish alternative food supplies in underdeveloped regions, such as setting up mobile clinics or food distribution centers that could be easily expanded.
#
# 2.  Establishing a system for distributing the newly available resources so these groups may actually receive them efficiently and on time.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 2 competitors.
# Each model has been given this question:
#
# You are an adviser to a small nation of 5 million people that, overnight, experiences an agricultural collapse that is projected to reduce domestic staple food production by 40% for the next 12 months because of a newly emergent plant pathogen. The country imports 30% of its food, has limited foreign-currency reserves, a healthcare system with hospital capacity for about 10% of the population at any given time, an economy where 35% of GDP and 25% of employment depend on agriculture, and significant regional inequality (poorer rural areas are most affected). You have 72 hours to present a policy plan to the president that minimizes excess mortality, prevents large-scale social unrest, and limits long-term economic damage over an 18‑month horizon. Produce the following in your answer:
# 1) a prioritized package of specific policy interventions (immediate emergency actions, 1–6 month measures, and 6–18 month recovery actions), with timelines and suggested allocations of scarce fiscal and logistical resources;
# 2) quantitative models or back-of-envelope calculations (with stated assumptions) estimating how each major intervention changes expected excess deaths, food availability per capita, and GDP change over 18 months;
# 3) clear indicators and threshold rules (measurable metrics and values) that should trigger policy adjustments or escalation;
# 4) a discussion of ethical trade-offs and distributional impacts (who wins/loses under your plan) and how you would mitigate harms to the most vulnerable;
# 5) plausible unintended consequences for each major intervention and specific mitigation strategies;
# 6) a prioritized list of additional data you would request immediately (ranked by expected value of information) and why; and
# 7) a 200‑word executive summary for non‑expert stakeholders.
# Be explicit about uncertainty, show your calculations, state all important assumptions, and where possible give ranges rather than single-point estimates.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Certainly. Below is a comprehensive policy advisory package addressing the sudden agricultural collapse in your nation.
#
# ---
#
# ### 1) Prioritized Package of Policy Interventions
#
# ---
#
# #### **Immediate Emergency Actions (Day 1–30)**
#
# - **a) Emergency Food Imports and Rationing**
#   - Rationale: Offset 40% staple food shortfall (~40% × 70% domestic food, since 30% imported).
#   - Action: Increase imports by emergency borrowing or concessional funding; implement temporary rationing.
#   - Allocation: ~40% of scarce foreign currency reserves; prioritize staple cereals.
#   - Logistics: Utilize military and national distribution networks.
#
# - **b) Emergency Cash Transfers / Food Vouchers Targeted at Vulnerable Populations**
#   - Focus: Rural poor (~25% of population, disproportionately affected).
#   - Allocation: 10% of emergency fiscal budget to ensure minimal caloric intake.
#
# - **c) Public Communication and Security Measures**
#   - Prevent panic and unrest via clear messaging, targeted law enforcement.
#
# ---
#
# #### **1–6 Month Measures**
#
# - **d) Expand Social Safety Nets and Nutrition Support**
#   - Expand vouchers and school feeding, community kitchens.
#   - Allocation: 20% of ongoing fiscal resources.
#
# - **e) Agricultural Diversification and Disease Management**
#   - Rapid deployment of fungicides, quarantine measures, research accelerated pathogen identification.
#   - Allocate resources to regional extension services.
#
# - **f) Stimulus for Agricultural Workers**
#   - Temporary public works programs paying in food/credits to maintain rural employment.
#
# - **g) Accelerate Local Production of Alternative Staples**
#   - Support short-cycle crops less affected by pathogen.
#
# ---
#
# #### **6–18 Month Recovery Actions**
#
# - **h) Invest in Resistant Crop Varieties and Diversification**
#   - Breed or import pathogen-resistant seeds; invest in agronomic research.
#
# - **i) Infrastructure and Market Reforms**
#   - Improve storage, transportation to minimize future losses.
#
# - **j) Economic Diversification Programs**
#   - Retraining programs for agricultural workers into other sectors to reduce vulnerability.
#
# ---
#
# ### Resource Allocation (Approximate):
#
# | Period          | Food Imports & Emergency Aid | Agricultural Support | Social Protection | Research & Infrastructure | Total Spending (% GDP) |
# |-----------------|------------------------------|---------------------|-------------------|---------------------------|-----------------------|
# | Immediate (0–1m) | 60%                          | 10%                 | 20%               | 10%                       | ~2.0%                 |
# | Short-term (1–6m)| 40%                          | 25%                 | 25%               | 10%                       | ~3.5%                 |
# | Medium-term (6–18m)| 20%                         | 35%                 | 20%               | 25%                       | ~3.0%                 |
#
# ---
#
# ### 2) Quantitative Estimates and Back-of-Envelope Calculations
#
# ---
#
# **Key assumptions:**
#
# - Population = 5 million
# - Baseline staple food consumption: 2,000 kcal/capita/day
# - Domestic production supplies 70% of staples; imports 30%
# - Agricultural GDP = 35% of total GDP; total GDP = $20 billion/year (assumed for calculations)
# - Healthcare capacity: can manage hospitalization of 500,000 patients at once
# - Excess mortality is linked to malnutrition and social unrest-related violence
# - Food gap without intervention = 0.4 × 0.7 = 28% loss of staple calories nationally (over 12 months)
#
# ---
#
# **Impact of interventions:**
#
# | Intervention                | Effect on Food Gap  | Effect on Excess Deaths (Est.)   | Effect on GDP (Est.)          |
# |----------------------------|--------------------|---------------------------------|------------------------------|
# | Emergency Imports & Rationing| Reduce gap from 28% to ~10% (imports cover 18% additional staples) | Prevent 60–80% of starvation-related deaths (reducing excess mortality from ~50,000 to ~10,000 over 12 months) | Short-term GDP hit limited to ~-2.5% (due to fiscal strain and import costs) |
# | Cash Transfers & Food Vouchers| Improve access by 5–7% | Reduce malnutrition in vulnerable by 50% (prevent ~10,000 deaths) | Stimulate rural purchasing power, offset GDP decline by +0.5% |
# | Agricultural interventions (fungicides, quarantine) | Potentially reduce production loss from 40% to 30% over 6 months | Lower excess deaths by additional ~5,000 | Partially stabilize agricultural GDP, prevent further 1–2% GDP decline |
# | Public works/stimulus  | Reduce rural unemployment by 10–15% | Indirect mortality reduction by maintaining incomes (~2,000 lives) | Limit broader economic contraction by +1% |
# | Medium-term breeding programs | Increase production 10–15% by year 2 | Long-term mortality effects negligible assuming adoption | GDP impact positive but after 12 months |
#
# ---
#
# **Calculation Example:**
#
# - Excess deaths baseline estimate without intervention:
#   - Assumed starvation-related mortality: ~1% excess death rate over 12 months without intervention (50,000 excess deaths).
# - Emergency imports close 18% shortfall → mortality reduced proportionally by ~65% (from 50,000 to ~18,000).
# - Add cash transfers/vouchers preventing 10,000 more deaths → down to ~8,000.
# - Other policies prevent further 3,000–4,000 deaths.
#
# ---
#
# ### 3) Indicators and Threshold Rules
#
# | Metric                           | Threshold Trigger                    | Response/Escalation                          |
# |---------------------------------|------------------------------------|---------------------------------------------|
# | Staple food availability (kcal/capita/day) | Falls below 1600 kcal (80% of baseline) | Increase imports and rationing intensification |
# | Malnutrition rates (children under 5)     | >15% severe malnutrition prevalence | Expand nutrition programs; activate international aid |
# | Price inflation in staple foods: > 15% monthly increase | Trigger price controls and anti-hoarding enforcement |
# | Unemployment (rural areas) >30%           | Launch expanded public works schemes |
# | Social unrest incidents > baseline by 50% | Deploy targeted security, emergency meetings with community leaders |
# | Hospital capacity utilization > 90% due to malnutrition/disease | Expand field hospitals; prioritize critical cases |
#
# ---
#
# ### 4) Ethical Trade-offs and Distributional Impacts
#
# - **Winners:** Urban poor, government-employed, recipients of aid programs, importers.
# - **Losers:** Smallholder farmers whose crops are failing, rural poor initially suffering losses, agricultural laborers facing unemployment risk.
# - **Mitigation:**
#   - Prioritize rural poor in food assistance and cash transfers.
#   - Public works in rural areas to provide income substitution.
#   - Transparent communications to prevent ethnic/regional tensions.
#   - Monitor aid distribution to avoid elite capture or corruption.
#
# ---
#
# ### 5) Unintended Consequences and Mitigation
#
# | Intervention             | Potential Issue                            | Mitigation Strategy                |
# |--------------------------|-------------------------------------------|----------------------------------|
# | Emergency Imports        | Foreign currency depletion; long-term dependency | Negotiate concessional loans; diversify suppliers |
# | Rationing                | Black markets; reduced incentives for production | Strict monitoring; incentivize local production |
# | Cash Transfers           | Inflationary pressure                     | Targeted transfers; monitor markets |
# | Fungicides/Quarantine    | Environmental damage; resistance development | Use integrated pest management; rotate chemicals |
# | Public Works             | Crowding out private sector employment   | Time-limited and targeted programs |
# | Economic diversification | Mismatch of skills leading to unemployment | Skills training aligned with demand |
#
# ---
#
# ### 6) Prioritized List of Additional Data Requests
#
# 1. **Current Food Stockpiles and Supply Chain Capacity** (to better time imports and distribution)
# 2. **Detailed Malnutrition and Health Surveillance Data** (to target interventions and monitor outcomes)
# 3. **Agricultural Production Data by Region and Crop Type** (to prioritize support and quarantine)
# 4. **Foreign Currency Reserves Details and Market Import Prices** (to plan imports and fiscal impact)
# 5. **Employment Figures in Rural vs Urban Sectors** (to design safety nets and stimulus)
# 6. **Social Unrest Incident Reports and Community Feedback** (to detect early signs of instability)
#
# ---
#
# ### 7) Executive Summary (200 words)
#
# The recent agricultural collapse is projected to reduce our staple food production by 40% for the next year, risking mass hunger and social instability, especially in our rural communities where 25% of our population and workforce resides. Immediate actions include emergency food imports to cover the shortfall and targeted rationing combined with cash transfers to protect the most vulnerable. These will reduce starvation-related excess deaths from an estimated 50,000 to below 10,000 over 12 months. Mid-term strategies will focus on managing the plant pathogen through quarantine and safe pesticide use, expanding social safety nets, and supporting affected farmers with alternative crops and public works programs to maintain incomes. Recovery efforts will involve investing in resilient crop varieties and economic diversification to buffer future shocks. Resource allocation prioritizes food imports and safety nets immediately (over 60% of emergency funds), with increased agricultural investment over the medium term. Continuous monitoring of food availability, prices, malnutrition, and social unrest will guide policy adjustments. We recognize the ethical imperative to protect rural poor farmers first while balancing national economic stability. While risks such as currency depletion and inflation exist, mitigation strategies are built in. Our success depends on transparent data collection, rapid action, and community engagement to safeguard lives and our nation’s future.
#
# ---
#
# Please let me know if you want me to create detailed models, specific budget allocation spreadsheets, or tailored communications materials.
#
# # Response from competitor 2
#
# I apologize, but as a text-based AI model, I am not capable of directly presenting policy interventions or mathematical models in the exact format requested by the question. Instead, I will provide a written response outlining the components required to address the situation.
#
# **Initial Response**
#
# Given the complexity and urgency of this crisis, it is crucial that we focus on immediate action while also laying the groundwork for a long-term recovery plan. Our primary objectives will be to minimize excess mortality, prevent social unrest, and stabilize the economy while addressing regional inequality.
#
# Here's an overview of the recommended policy interventions:
#
# 1.  **Immediate Emergency Actions:**
#     *   Establish a Food Reserve Management Committee to oversee a strategic allocation of cash reserves.
#     *   Activate the National Health System with emergency funding and allocate hospital space for medical responders.
#     *   Implement a Food Distribution Framework, involving all regions and sectors, to ensure access to vital staple foods.
#
# 2.  **1–6 Month Measures:**
#     *   Conduct an intensive agricultural survey to understand current crop health status.
#     *   Develop & implement sustainable farming methods using the new technology available.
#     *   Revise import policies, focusing on staple items while promoting a balance of imports based on national availability and affordability.
#
# 3.  **6–18 Month Recovery Actions:**
#     *   Create long-term agricultural training programs with emphasis on pathogen resistance techniques as the solution.
#     *   Implement a Food Security Guarantee Scheme: offering subsidies in form of cash or food vouchers for those most reliant.
#     *   Gradually resume partial-scale agriculture and gradually restart all lost parts of the economy.
#
# **Modeling Estimates**
#
# For simplicity, these estimates are based on simplistic models.
#
# Here's how our scenario changes over time.
#
# *   Initial Excess Deaths: Assuming an increase of 200 deaths/12 due to immediate effects.
#     *   This model estimates a potential excess mortality rate (per capita) by month and assuming initial food availability.
# *   Food Availability Per Capita:
#     -Assuming that the country will achieve 60% of what's available in the beginning at the end of 3 months.
#     -Following this, the food availability per person stays above the baseline for 6-8 months after that.
#      *   By the seventh month our available food reaches 80%, by the eighth it reaches or exceeds national production capacity.
#
# *   GDP Impact:
#     -The initial impact can account for a decrease in 12-months of production (with estimates given as 2,000 in pre-infection levels) with a projected GDP that at the end of that period would be around $4.7 billion.
#
# Some critical factors influencing how well we do will include global trends, economic forecasts, climate changes and various government policies along a few different paths from here onward.
#
# **Indicators & Threshold Rules**
#
# Some key metrics to monitor for triggering immediate adjustments or escalation could include:
#
# 1.  Daily death rates above the national standard (0.015 per million).
# 2.  Proportion of the Food Reserve that's been depleted after six months.
# 3.  GDP decrease reaching at least 5% of the baseline levels over a three-month period.
#
# **Ethical Trade-Offs & Distributional Impacts**
#
# The distribution aspects are complicated given regional inequality and how such unequal access might play into our policy mix to minimize excess mortalities to be addressed.
#
# However, to address this we should set up policies so as every critical individual group (who is most at-risk of going over some threshold for mortality given their current situation) could benefit directly or have a direct stake in the resources we put together.
#
# **Unintended Consequences & Mitigation**
#
# Potential unintended consequences that may arise might include higher-than-expected economic costs from supply chain disruptions and higher demand on healthcare systems. Here are mitigation strategies aimed at reducing these risks:
#
# 1.  Implementing measures to quickly establish alternative food supplies in underdeveloped regions, such as setting up mobile clinics or food distribution centers that could be easily expanded.
#
# 2.  Establishing a system for distributing the newly available resources so these groups may actually receive them efficiently and on time.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gpt-4.1-mini
# Rank 2: llama3.2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
question = "Please come up with a challenging NBA basketball hot take that I can ask a number of LLMs to evaluate their intelligence. "
question += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": question}]

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages,
)

question = response.choices[0].message.content
print(question)
# Out:
# Is it plausible to argue that Khris Middleton, rather than Giannis Antetokounmpo, has been the true cornerstone of the Milwaukee Bucks' championship success, and how does this assertion challenge conventional metrics used to evaluate player impact in basketball?

# %%
question_NBA = [{"role": "user", "content": question}]
openai_response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=question_NBA,
)

openai_response = openai_response.choices[0].message.content
print(openai_response)

display(Markdown(openai_response))
# Out:
# It is an intriguing and somewhat contrarian argument to position Khris Middleton—not Giannis Antetokounmpo—as the true cornerstone of the Milwaukee Bucks' championship success. While the conventional narrative overwhelmingly credits Giannis as the franchise cornerstone due to his superstar status, MVP awards, and dominant individual impact, a closer analysis of Middleton’s role offers a nuanced perspective that challenges standard metrics and traditional evaluation of player impact.
#
# ### Why the Argument for Middleton as the Cornerstone Is Plausible
#
# 1. **Clutch Performance and Finals Impact**
#    Middleton’s contributions in the 2021 NBA Finals were undeniably critical. His scoring efficiency, defensive versatility, and ability to hit pivotal shots (notably in Game 6) helped swing the series in Milwaukee’s favor. While Giannis’s performances received widespread attention, Middleton’s steady, clutch presence was a stabilizing factor that conventional box score stats (points, rebounds, assists) sometimes undervalue since it includes elements like gravity, spacing, and defensive communication.
#
# 2. **Offensive Versatility and Spacing**
#    Middleton’s role as a secondary creator and shooter allowed Giannis to dominate in the paint. His ability to space the floor and create his own shot opened driving lanes for Giannis and prevented defenses from focusing solely on the Greek Freak. Conventional metrics may credit overall team success and win shares primarily to the best player, but Middleton’s gravity and efficient shooting arguably lifted team offensive efficiency beyond what raw stats capture.
#
# 3. **Two-Way Impact Beyond Counting Stats**
#    Advanced metrics like Defensive Real Plus-Minus (DRPM) and on/off splits suggest Middleton’s presence on the floor reduces opponent scoring and improves Bucks defensive cohesion. His versatility defending multiple positions often goes unnoticed in simpler stats, challenging the idea that impact is solely measurable by points, rebounds, or even box plus-minus.
#
# 4. **Consistency and Reliability**
#    While Giannis occasionally carried the team in spectacular fashion, Middleton’s consistency over multiple seasons and games—especially during critical playoff stretches—made Milwaukee’s approach multi-dimensional. Basketball’s heavy reliance on star dominance in analytic narratives sometimes discounts the importance of reliable complementary stars who reduce variance and matchup exploitation.
#
# ### How This Challenges Conventional Metrics for Player Impact
#
# 1. **Overreliance on Volume Stats and Star-Centric Evaluations**
#    Metrics like PER, Win Shares, and VORP tend to reward high-usage, high-volume players, often skewing evaluations toward clear superstars like Giannis. Middleton’s efficient role player-type impact is harder to quantify, revealing a blind spot in metrics that fail to capture spatial impact, gravity, and intangibles like defensive rotations.
#
# 2. **Underappreciation of Role Player “Glue Guys”**
#    Conventional metrics can undervalue players who excel as “glue guys”—those whose contributions facilitate team success without piling up flashy stats. The argument that Middleton is a critical cornerstone highlights the need to refine impact metrics to better incorporate on/off effects, lineup synergy, and context-dependent roles.
#
# 3. **The Importance of Contextual and Situational Analysis**
#    The case for Middleton underscores the importance of qualitative film study and situational analysis to understand player impact. Conventional box score-based assessments miss subtleties such as clutch performance, defensive communication, and positional switching on defense that influence outcomes dramatically.
#
# ### Conclusion
#
# While it is not mainstream to name Khris Middleton the true cornerstone over Giannis Antetokounmpo, doing so is a plausible case that pushes us to rethink how we evaluate impact in basketball. It underlines the limitations of traditional and even some advanced metrics in capturing nuanced contributions of complementary stars in championship teams. By appreciating Middleton’s multi-faceted role—offensively, defensively, and situationally—we gain a fuller picture of the dynamics behind Milwaukee’s title run, which challenges the star-centric orthodoxy dominating basketball evaluation discourse.
# It is an intriguing and somewhat contrarian argument to position Khris Middleton—not Giannis Antetokounmpo—as the true cornerstone of the Milwaukee Bucks' championship success. While the conventional narrative overwhelmingly credits Giannis as the franchise cornerstone due to his superstar status, MVP awards, and dominant individual impact, a closer analysis of Middleton’s role offers a nuanced perspective that challenges standard metrics and traditional evaluation of player impact.
#
# ### Why the Argument for Middleton as the Cornerstone Is Plausible
#
# 1. **Clutch Performance and Finals Impact**
#    Middleton’s contributions in the 2021 NBA Finals were undeniably critical. His scoring efficiency, defensive versatility, and ability to hit pivotal shots (notably in Game 6) helped swing the series in Milwaukee’s favor. While Giannis’s performances received widespread attention, Middleton’s steady, clutch presence was a stabilizing factor that conventional box score stats (points, rebounds, assists) sometimes undervalue since it includes elements like gravity, spacing, and defensive communication.
#
# 2. **Offensive Versatility and Spacing**
#    Middleton’s role as a secondary creator and shooter allowed Giannis to dominate in the paint. His ability to space the floor and create his own shot opened driving lanes for Giannis and prevented defenses from focusing solely on the Greek Freak. Conventional metrics may credit overall team success and win shares primarily to the best player, but Middleton’s gravity and efficient shooting arguably lifted team offensive efficiency beyond what raw stats capture.
#
# 3. **Two-Way Impact Beyond Counting Stats**
#    Advanced metrics like Defensive Real Plus-Minus (DRPM) and on/off splits suggest Middleton’s presence on the floor reduces opponent scoring and improves Bucks defensive cohesion. His versatility defending multiple positions often goes unnoticed in simpler stats, challenging the idea that impact is solely measurable by points, rebounds, or even box plus-minus.
#
# 4. **Consistency and Reliability**
#    While Giannis occasionally carried the team in spectacular fashion, Middleton’s consistency over multiple seasons and games—especially during critical playoff stretches—made Milwaukee’s approach multi-dimensional. Basketball’s heavy reliance on star dominance in analytic narratives sometimes discounts the importance of reliable complementary stars who reduce variance and matchup exploitation.
#
# ### How This Challenges Conventional Metrics for Player Impact
#
# 1. **Overreliance on Volume Stats and Star-Centric Evaluations**
#    Metrics like PER, Win Shares, and VORP tend to reward high-usage, high-volume players, often skewing evaluations toward clear superstars like Giannis. Middleton’s efficient role player-type impact is harder to quantify, revealing a blind spot in metrics that fail to capture spatial impact, gravity, and intangibles like defensive rotations.
#
# 2. **Underappreciation of Role Player “Glue Guys”**
#    Conventional metrics can undervalue players who excel as “glue guys”—those whose contributions facilitate team success without piling up flashy stats. The argument that Middleton is a critical cornerstone highlights the need to refine impact metrics to better incorporate on/off effects, lineup synergy, and context-dependent roles.
#
# 3. **The Importance of Contextual and Situational Analysis**
#    The case for Middleton underscores the importance of qualitative film study and situational analysis to understand player impact. Conventional box score-based assessments miss subtleties such as clutch performance, defensive communication, and positional switching on defense that influence outcomes dramatically.
#
# ### Conclusion
#
# While it is not mainstream to name Khris Middleton the true cornerstone over Giannis Antetokounmpo, doing so is a plausible case that pushes us to rethink how we evaluate impact in basketball. It underlines the limitations of traditional and even some advanced metrics in capturing nuanced contributions of complementary stars in championship teams. By appreciating Middleton’s multi-faceted role—offensively, defensively, and situationally—we gain a fuller picture of the dynamics behind Milwaukee’s title run, which challenges the star-centric orthodoxy dominating basketball evaluation discourse.

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

ollama_response = ollama.chat.completions.create(model=model_name, messages=question_NBA)
ollama_response = ollama_response.choices[0].message.content
display(Markdown(ollama_response))
# Out:
# The case for Kris Middleton as the true cornerstone of the Milwaukee Bucks' championship success is an intriguing one. While Giannis Antetokounmpo was undoubtedly a key factor in their 2021 NBA Championship win, Middleton's contributions over the years have consistently demonstrated his ability to make significant impacts on both ends of the court. Let's delve into why this assertion challenges conventional metrics used to evaluate player impact:
#
# Conventional Metrics:
# When evaluating players like Giannis and Middleton, traditional statistics often prioritize raw numbers such as points per game (PTS), rebounds per game (REB), assists per game (AST), blocks per game (BLK), and steals per game (STL). However, conventional metrics can sometimes oversimplify a player's overall value.
#
# Middleton Challenges Conventional Metrics:
#
# 1. Consistency: Middleton has played with incredible durability throughout his career, averaging over 50 games played per season despite dealing with various injuries on both legs. This demonstrates his commitment to being available for the Bucks' biggest games.
# 2. Efficiency: Despite never being the primary scorer, Middleton is an elite shooter (43.5% three-point range) and possesses a well-rounded skillset, showcasing his versatility on offense. He's also made significant strides in scoring efficiency over his career.
# 3. Defensive Impact: Middleton has evolved into one of the NBA's top perimeter defenders, making waves with his shot-blocking and ability to lock down elite scorers. His increased defensive presence helps balance out the Bucks' team defense.
#
# Middleton's case can be extended beyond traditional statistics by considering other factors such as:
#
# * Intangibles: Middleton has consistently demonstrated a "team-first" mentality during major playoff rungs, displaying leadership qualities when given opportunities.
# * Playmaking Ability: Despite not being a primary playmaker, Middleton has shown surprising skill in reading the game and directing his teammates to better shots or open space for Giannis.
# * Career Resilience: Despite struggling with minor injuries or minor nagging issues periodically, Middleton has consistently returned to form.
#
# Challenging Conventional Metrics:
# The assertion that Kris Middleton is the true cornerstone of the Milwaukee Bucks championship success could be seen as challenging several conventional metrics:
#
# 1.Maintaining high overall numbers without being a primary scorer forces evaluators to acknowledge Middleton's value beyond his scoring totals.
# 2. His ability to provide elite perimeter defense and contribute significantly in supporting roles, making him more difficult to quantify using simple statistics.
#
# Giannis and the Bucks:
# While Giannis remains an incredible player with numerous MVP awards under his belt, Middleton is undoubtedly a crucial component of the team. During their championship run, Middleton put up some remarkable numbers (16.2 points, 5.6 rebounds, 3.0 assists per game) while being instrumental in stretching defenses. This made him a much-needed outlet for Giannis to attack and create space from other defenders.
#
# Middleton's sustained excellence over the past five years underlines his true value to Milwaukee: As an elite role player who allows his team's best talent (like Giannis and Khris himself) to excel while consistently delivering at a high level.
#
# The Case
# In conclusion, if we reframe how we evaluate basketball players' impacts using metrics that emphasize teamwork, skillset variety, durability, leadership qualities, and defensive prowess, Kris Middleton's value as the true cornerstone of the Milwaukee Bucks' championship success stands out more clearly. By recognizing these qualities in his playmaking capacity, perimeter defense, ability to be a top-notch shooter without necessarily being an elite scorer, and high level of career resilience, we might view Middleton with a fresh perspective.
#
# While Giannis will always remain at the heart of the team, Kris Middleton is indeed the glue that has made their championship successes possible.

# %%
answers = []
answers.append(openai_response)
answers.append(ollama_response)
